# %%
from bs4 import BeautifulSoup
import re

with open(f'兑现承诺！直播土木行业从入职到跑路！ (3.2  难受，被打回来俩文件 614楼)\兑现承诺！直播土木行业从入职到跑路！ (3.2  难受，被打回来俩文件 614楼)1.html', 'r', encoding='gbk') as f:
    soup = BeautifulSoup(f, 'lxml')
    i=621
    l = soup.find_all(id=re.compile(r"postcontent\d+"))
    s = soup.find_all(id=re.compile(r'postauthor\d+'))
    pattern = re.compile(r'\d+')
    for i in s:
        uid = pattern.findall(i['href'])[0]
        print(uid)
    for j in l:
        print(j.text)
# Out:
# 60473328
# 60473328
# 6913411
# 2039897
# 61778413
# 39905062
# 60801959
# 60817002
# 63110974
# 62289761
# 9620620
# 42909562
# 63254714
# 42142756
# 62866976
# 62052710
# 62009203
# 60118444
# 26068962
# 62617698
# ...

# %%
from bs4 import BeautifulSoup
import re

name="五年不见，你还会梦到她吗"
with open(f'{name}/{name}1.html', 'r', encoding='gbk') as f:
    soup = BeautifulSoup(f, 'lxml')
    l = soup.find("title").text
    p2 = re.compile(r'(.*)\sNGA玩家社区')
    s2=p2.findall(l)[0]
    print(s2)
    s3=soup.find(id='pageBtnHere')
    p4=re.compile(r',1:(\d+)')
    s4=p4.findall(s3.next_sibling.text)[0]
    print(s4)
# Out:
# 五年没见面的人   你还会梦见她吗？
# 4

# %%
name="走不出来"
page=0
print(name+f'/{name}{page}.html')
f = open(name+f'/{name}{page}.html', "w+", encoding='gbk')
f.write("hello")

f.close()
# Out:
# 走不出来/走不出来0.html
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\zypha\workspace\web\nga\firstSexNga.ipynb Cell 3' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/zypha/workspace/web/nga/firstSexNga.ipynb#ch0000002?line=1'>2</a> page=0
#       <a href='vscode-notebook-cell:/c%3A/Users/zypha/workspace/web/nga/firstSexNga.ipynb#ch0000002?line=2'>3</a> print(name+f'/{name}{page}.html')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/zypha/workspace/web/nga/firstSexNga.ipynb#ch0000002?line=3'>4</a> f = open(name+f'/{name}{page}.html', "w+", encoding='gbk')
#       <a href='vscode-notebook-cell:/c%3A/Users/zypha/workspace/web/nga/firstSexNga.ipynb#ch0000002?line=4'>5</a> f.write("hello")
#       <a href='vscode-notebook-cell:/c%3A/Users/zypha/workspace/web/nga/firstSexNga.ipynb#ch0000002?line=6'>7</a> f.close()
#
# ...
